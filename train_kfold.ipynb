# %%
import torch, torchvision
import os
import random
import logging #Se renseigner, par encore utilisé
import dataset

import constants as cst
import numpy as np
import torch.nn as nn
import torchvision.transforms as transforms
# import matplotlib.pyplot as plt
import torch.nn.functional as F

import loss_fn
from unet import UNET

# %%
TERM = "VC"
EXTRA = "ALL"

DATASET = "/datasets/zebrafish_images"
MASKS = "/datasets/zebrafish_vertebraes"

# %%
random.seed(cst.SEED)
torch.manual_seed(cst.SEED)
np.random.seed(cst.SEED)

SIZE = (384, 512)

DEVICE_NAME = "cpu"
if torch.cuda.is_available():
    DEVICE_NAME = 'cuda:0'
DEVICE = torch.device(DEVICE_NAME)

transform = transforms.Compose([transforms.Resize(SIZE),
                                transforms.Pad((0, 64, 0, 64))])
untransform = transforms.Compose([transforms.CenterCrop(SIZE),
                                 transforms.Resize((1932, 2576))])

model = UNET(3, 2)
overall_best_model = UNET(3, 2)
overall_best_model = model
model.to(DEVICE)

best_fold = 0
overall_best = 10
best_fold_epoch = 0
fold_best_vals = []

image_folder = DATASET
mask_folder = MASKS


for fold in range(cst.FOLDS):
    # Datasets and loaders
    training_set = dataset.ZebrafishDataset_KFold_v2(image_folder,
                                                  mask_folder,
                                                  actual_fold=fold,
                                                  dataset="train",
                                                  folds=5)
    validation_set = dataset.ZebrafishDataset_KFold_v2(image_folder,
                                                    mask_folder,
                                                    actual_fold=fold,
                                                    dataset="validate",
                                                    folds=5)
    testing_set = dataset.ZebrafishDataset_KFold_v2(image_folder,
                                                 mask_folder,
                                                 actual_fold=fold,
                                                 dataset="test",
                                                 folds=5)

    training_loader = torch.utils.data.DataLoader(training_set,
                                                  batch_size=cst.BATCH_SIZE,
                                                  shuffle=True,
                                                  num_workers=cst.WORKERS)

    validation_loader = torch.utils.data.DataLoader(validation_set,
                                                    batch_size=cst.BATCH_SIZE,
                                                    shuffle=True,
                                                    num_workers=cst.WORKERS)

    testing_loader = torch.utils.data.DataLoader(testing_set,
                                                 batch_size=1,
                                                 shuffle=True,
                                                 num_workers=cst.WORKERS)

    # (Channels x Classes)
    model = UNET(3, 2)
    best_model = UNET(3, 2)
    best_model = model
    model.to(DEVICE)

    criterion = nn.CrossEntropyLoss()
    criterion_string = "CE"

    if cst.LOSS == "Dice":
        print("Dice")
        criterion = loss_fn.DiceLoss()
        criterion_string = "DCE"
    if cst.LOSS == "IOU":
        print("IOU")
        criterion = loss_fn.IoULoss()
        criterion_string = "IOU"
    if cst.LOSS == "Tversky":
        print("Twersky")
        criterion = loss_fn.TverskyLoss()
        criterion_string = "Tversky"

    optimiser = torch.optim.Adam(model.parameters(), lr=cst.LEARNING_RATE, weight_decay=cst.WEIGHT_DECAY)
    optimiser_string = "ADAM" + "_" + "LR" + str(cst.LEARNING_RATE) + "_" + "WD" + str(cst.WEIGHT_DECAY)

    if cst.OPTIMIZER == "SGD":
        optimizer = torch.optim.SGD(model.parameters(),
                                    lr=cst.LEARNING_RATE,
                                    momentum=cst.MOMENTUM,
                                    weight_decay=cst.WEIGHT_DECAY)
        optimiser_string = "SGD" + "_" + "LR" + str(cst.LEARNING_RATE) + "_" + "M" + str(cst.MOMENTUM)
        optimiser_string += "_" + "WD" + str(cst.WEIGHT_DECAY)

    model.eval()
    with torch.no_grad():
        val_loss = []
        for images, masks, names in validation_loader:
            images = transform(images)
            outputs = model(images.to(DEVICE))
            outputs = untransform(outputs)

            masks = masks.type(torch.LongTensor)
            masks = torch.squeeze(masks, 1)

            if cst.LOSS == "CE":
                vloss = criterion(outputs, masks.to(DEVICE))
            else:
                vloss = criterion(outputs, F.one_hot(masks, 2).permute(0, 3, 1, 2).float())

            loss = vloss.detach().item()
            val_loss.append(loss)

        loss = np.mean(val_loss)
        print("Validation loss before training: {}".format(loss))

    best_val = loss
    best_epoch = 0

    params_string = "Params" + "_" + "Epoch" + str(cst.EPOCHS) + "_" + "BS" + str(cst.BATCH_SIZE)
    params_string += "_" + "W" + str(cst.WORKERS)

    epochs_train_losses = []
    epochs_val_losses = []
    for i in range(cst.EPOCHS):
        print("Starting epoch {}".format(i+1), end=". ")

        model.train()
        train_loss = []
        for images, masks, names in training_loader:
            images = transform(images)
            outputs = model(images.to(DEVICE))
            outputs = untransform(outputs)

            masks = masks.type(torch.LongTensor)
            masks = torch.squeeze(masks, 1)

            if cst.LOSS == "CE":
                tloss = criterion(outputs, masks.to(DEVICE))
            else:
                tloss = criterion(outputs, F.one_hot(masks, 2).permute(0, 3, 1, 2).float())

            loss = tloss.detach().item()
            train_loss.append(loss)

            optimiser.zero_grad()
            tloss.backward()
            optimiser.step()

        #print("d")
        loss = np.mean(train_loss)
        epochs_train_losses.append(loss)
        print("Trained: {}".format(loss), end=". ")

        model.eval()
        with torch.no_grad():
            val_loss = []
            for images, masks, names in validation_loader:
                images = transform(images)
                outputs = model(images.to(DEVICE))
                outputs = untransform(outputs)

                masks = masks.type(torch.LongTensor)
                masks = torch.squeeze(masks, 1)

                if cst.LOSS == "CE":
                    vloss = criterion(outputs, masks.to(DEVICE))
                else:
                    vloss = criterion(outputs, F.one_hot(masks, 2).permute(0, 3, 1, 2).float())

                loss = vloss.detach().item()
                val_loss.append(loss)

            loss = np.mean(val_loss)
            epochs_val_losses.append(loss)
            print("Validation: {}.".format(loss))

            if loss < best_val:
                best_val = loss
                best_model = model
                best_epoch = i+1

    #print("Training: {}".format(epochs_train_losses))
    #print("Validating: {}".format(epochs_val_losses))
    print("Best score: {}".format(best_val))

    #model_filepath = os.path.join(cst.MODEL, model_name)
    #best_filepath = os.path.join(cst.MODEL, best_name)
    #torch.save(model.state_dict(), model_filepath)
    #torch.save(best_model.state_dict(), best_filepath)

    fold_best_vals.append(best_val)
    
    if best_val < overall_best:
        overall_best = best_val
        overall_best_model = best_model
        best_fold_epoch = best_epoch
        best_fold = fold

    print("--------------------")
    print("Fold: {}".format(fold))
    print("Last val: {}".format(loss))
    print("Best val: {}".format(best_val))
    print("--------------------")


    """
    index = [i+1 for i in range(cst.EPOCHS)]
    plt.plot(index, epochs_train_losses, label="Training")
    plt.plot(index, epochs_val_losses, label="Validation")
    plt.title(cst.LOSS)
    plt.ylabel("Loss")
    plt.xlabel("Epochs")
    plt.legend()
    plot_name = name + ".png"
    plt.savefig(plot_name)
    """

name = TERM + "_" + EXTRA + "_Fold" + str(best_fold) +  "_EPOCH" + str(best_fold_epoch) + "_Val" + str(best_val)
name = name + criterion_string + "_" + optimiser_string + "_" + params_string
model_name = name + ".pth"
best_filepath = os.path.join(cst.MODEL, model_name)
#torch.save(overall_best_model.state_dict(), best_filepath)

print("-------------------------")
print("-----------END-----------")
print("-------------------------")
print("Best fold: {}".format(best_fold))
print("Best validation loss: {}".format(overall_best))
print("Best epoch: {}".format(best_fold_epoch))
print("Mean val of folds: {}".format(np.mean(fold_best_vals)))
print("Best vals for each fold:")
a = 0
for item in fold_best_vals:
    print("Fold :{}".format(a+1), end=" - ")
    print("Val: {}".format(item))
# Out:
# Training set length: 118
# Validation set length: 30
# Testing set length: 29
# Validation loss before training: 0.6688893884420395
# Starting epoch 1. Trained: 0.6770721395810445. Validation: 0.6640378162264824.
# Starting epoch 2. Trained: 0.6568287551403046. Validation: 0.6479606181383133.
# Starting epoch 3. Trained: 0.6287015855312348. Validation: 0.6060688868165016.
# Starting epoch 4. Trained: 0.5605874558289846. Validation: 0.48322538658976555.
# Starting epoch 5. Trained: 0.13975270371884108. Validation: 0.042093385476619005.
# Starting epoch 6. Trained: 0.01889147103453676. Validation: 0.018525584368035197.
# Starting epoch 7. Trained: 0.015393812116235495. Validation: 0.015903846826404333.
# Starting epoch 8. Trained: 0.014059053920209407. Validation: 0.014704628963954747.
# Starting epoch 9. Trained: 0.013171347634245953. Validation: 0.013860409846529365.
# Starting epoch 10. Trained: 0.012542510265484452. Validation: 0.013865678803995252.
# Starting epoch 11. Trained: 0.011924838383371631. Validation: 0.012909547542221844.
# Starting epoch 12. Trained: 0.011459777007500331. Validation: 0.012831780593842268.
# Starting epoch 13. Trained: 0.011213128780946135. Validation: 0.012982740765437484.
# Starting epoch 14. Trained: 0.010785604423532883. Validation: 0.013026501634158194.
# Starting epoch 15. Trained: 0.010580871626734734. Validation: 0.012364097696263343.
# Starting epoch 16. Trained: 0.010322566330432891. Validation: 0.012457478675059974.
# Starting epoch 17. Trained: 0.01015851207387944. Validation: 0.01204501953907311.
# Starting epoch 18. Trained: 0.009910374615962307. Validation: 0.011688924278132617.
# Starting epoch 19. Trained: 0.009666767561187346. Validation: 0.011806074413470924.
# Starting epoch 20. Trained: 0.009653599482650559. Validation: 0.012128471047617495.
# Starting epoch 21. Trained: 0.009464392252266408. Validation: 0.011680206516757607.
# Starting epoch 22. Trained: 0.009351866273209452. Validation: 0.011971825268119574.
# Starting epoch 23. Trained: 0.00927093201316893. Validation: 0.011738621280528605.
# Starting epoch 24. Trained: 0.009060745049888888. Validation: 0.011229299707338214.
# Starting epoch 25. Trained: 0.008853034504378835. Validation: 0.01091727043967694.
# Starting epoch 26. Trained: 0.00876247853351136. Validation: 0.01137011416722089.
# Starting epoch 27. Trained: 0.008727985744675001. Validation: 0.010869186138734221.
# Starting epoch 28. Trained: 0.008581705655281742. Validation: 0.01118218689225614.
# Starting epoch 29. Trained: 0.008557474271704753. Validation: 0.011365645681507885.
# Starting epoch 30. Trained: 0.00843823910690844. Validation: 0.011316543910652399.
# Starting epoch 31. Trained: 0.008458375496168931. Validation: 0.010997789620887488.
# Starting epoch 32. Trained: 0.008422587051366765. Validation: 0.011077998438850045.
# Starting epoch 33. Trained: 0.008252727597331007. Validation: 0.011261901177931577.
# Starting epoch 34. Trained: 0.008197966264560819. Validation: 0.01161572674755007.
# Starting epoch 35. Trained: 0.008014600568761429. Validation: 0.011040270910598338.
# Starting epoch 36. Trained: 0.008104909909889102. Validation: 0.011648794752545655.
# Starting epoch 37. Trained: 0.008012105027834575. Validation: 0.011567701702006161.
# Starting epoch 38. Trained: 0.007869255216792225. Validation: 0.010898825014010072.
# Starting epoch 39. Trained: 0.007762428722344339. Validation: 0.011438067071139812.
# Starting epoch 40. Trained: 0.007722602722545465. Validation: 0.011296818556729704.
# Best score: 0.010869186138734221
# --------------------
# Fold: 0
# Last val: 0.011296818556729704
# Best val: 0.010869186138734221
# --------------------
# Training set length: 118
# Validation set length: 30
# Testing set length: 29
# Validation loss before training: 0.7043385654687881
# Starting epoch 1. Trained: 0.6939873198668162. Validation: 0.6932176724076271.
# Starting epoch 2. Trained: 0.6696399847666422. Validation: 0.6744426116347313.
# Starting epoch 3. Trained: 0.6432491481304169. Validation: 0.6274622529745102.
# Starting epoch 4. Trained: 0.592209925254186. Validation: 0.502984307706356.
# Starting epoch 5. Trained: 0.17528998504082363. Validation: 0.03889293363317847.
# Starting epoch 6. Trained: 0.02051200792193413. Validation: 0.020911935600452125.
# Starting epoch 7. Trained: 0.01713783508166671. Validation: 0.018532929942011833.
# Starting epoch 8. Trained: 0.01580300641556581. Validation: 0.01697395497467369.
# Starting epoch 9. Trained: 0.014608373834441106. Validation: 0.01600775879342109.
# Starting epoch 10. Trained: 0.013746343925595284. Validation: 0.01472140138503164.
# Starting epoch 11. Trained: 0.012947258849938711. Validation: 0.014120368286967278.
# Starting epoch 12. Trained: 0.012440304768582185. Validation: 0.013766417279839516.
# Starting epoch 13. Trained: 0.01188296580997606. Validation: 0.01246694615110755.
# Starting epoch 14. Trained: 0.011432240313539902. Validation: 0.012585283955559134.
# Starting epoch 15. Trained: 0.011416421085596085. Validation: 0.012061969260685146.
# Starting epoch 16. Trained: 0.01085970865872999. Validation: 0.011990718892775476.
# Starting epoch 17. Trained: 0.01061865552328527. Validation: 0.011584078310988843.
# Starting epoch 18. Trained: 0.01028537427385648. Validation: 0.011005241249222308.
# Starting epoch 19. Trained: 0.010156725983445842. Validation: 0.011299505014903843.
# Starting epoch 20. Trained: 0.009953857011472186. Validation: 0.011177846230566502.
# Starting epoch 21. Trained: 0.009854148421436549. Validation: 0.011347729479894042.
# Starting epoch 22. Trained: 0.00960199530236423. Validation: 0.010886040050536394.
# Starting epoch 23. Trained: 0.00948959969294568. Validation: 0.010974084259942174.
# Starting epoch 24. Trained: 0.00936557543464005. Validation: 0.01095054717734456.
# Starting epoch 25. Trained: 0.009198530002807577. Validation: 0.01099518162664026.
# Starting epoch 26. Trained: 0.009200153686106206. Validation: 0.011088737868703902.
# Starting epoch 27. Trained: 0.00912981069025894. Validation: 0.01084935781545937.
# Starting epoch 28. Trained: 0.00903825721082588. Validation: 0.010603527713101357.
# Starting epoch 29. Trained: 0.008847357456882794. Validation: 0.010343681438826025.
# Starting epoch 30. Trained: 0.008946343977004289. Validation: 0.011185256415046751.
# Starting epoch 31. Trained: 0.008642221319799621. Validation: 0.0103585040778853.
# Starting epoch 32. Trained: 0.008619105986629924. Validation: 0.01083111425396055.
# Starting epoch 33. Trained: 0.008615845752259096. Validation: 0.010518297203816473.
# Starting epoch 34. Trained: 0.008556237925464909. Validation: 0.010910952114500105.
# Starting epoch 35. Trained: 0.008450056069220106. Validation: 0.010456942778546363.
# Starting epoch 36. Trained: 0.008376874262467027. Validation: 0.010292779188603163.
# Starting epoch 37. Trained: 0.008270575742547711. Validation: 0.010394275421276689.
# Starting epoch 38. Trained: 0.008303339468936126. Validation: 0.010305931442417204.
# Starting epoch 39. Trained: 0.008156402052069705. Validation: 0.010454287636093795.
# Starting epoch 40. Trained: 0.008065695905437072. Validation: 0.010406645480543375.
# Best score: 0.010292779188603163
# --------------------
# Fold: 1
# Last val: 0.010406645480543375
# Best val: 0.010292779188603163
# --------------------
# Training set length: 118
# Validation set length: 30
# Testing set length: 29
# Validation loss before training: 0.7550657913088799
# Starting epoch 1. Trained: 0.7395996809005737. Validation: 0.748923271894455.
# Starting epoch 2. Trained: 0.7093136568864187. Validation: 0.7099854350090027.
# Starting epoch 3. Trained: 0.6758724967638652. Validation: 0.6524104848504066.
# Starting epoch 4. Trained: 0.5961579084396362. Validation: 0.43898874521255493.
# Starting epoch 5. Trained: 0.10287568550556898. Validation: 0.020048534614033997.
# Starting epoch 6. Trained: 0.017033061105757953. Validation: 0.01570075936615467.
# Starting epoch 7. Trained: 0.014191745532055695. Validation: 0.014540755073539913.
# Starting epoch 8. Trained: 0.01306742699816823. Validation: 0.014302241965197027.
# Starting epoch 9. Trained: 0.012426520278677345. Validation: 0.013752123224548995.
# Starting epoch 10. Trained: 0.012026791305591663. Validation: 0.013711932464502752.
# Starting epoch 11. Trained: 0.011615962504098814. Validation: 0.012875470682047307.
# Starting epoch 12. Trained: 0.011254458874464034. Validation: 0.012718178913928568.
# Starting epoch 13. Trained: 0.01093612218586107. Validation: 0.012512739514932036.
# Starting epoch 14. Trained: 0.010527532796065013. Validation: 0.012738144840113819.
# Starting epoch 15. Trained: 0.010345885995775461. Validation: 0.01314802299020812.
# Starting epoch 16. Trained: 0.010051740178217491. Validation: 0.011694032698869705.
# Starting epoch 17. Trained: 0.009869632202511032. Validation: 0.012611232115887105.
# Starting epoch 18. Trained: 0.009571281416962544. Validation: 0.012091148411855102.
# Starting epoch 19. Trained: 0.009393466962501406. Validation: 0.0121015744516626.
# Starting epoch 20. Trained: 0.009251934646939238. Validation: 0.011795636150054634.
# Starting epoch 21. Trained: 0.009175615136822064. Validation: 0.012095364392735064.
# Starting epoch 22. Trained: 0.00907015954144299. Validation: 0.01162389456294477.
# Starting epoch 23. Trained: 0.008895614184439182. Validation: 0.012874220963567495.
# Starting epoch 24. Trained: 0.008793892913187544. Validation: 0.011892731883563101.
# Starting epoch 25. Trained: 0.008632859106486042. Validation: 0.011728539247997105.
# Starting epoch 26. Trained: 0.00845487965270877. Validation: 0.013013598276302218.
# Starting epoch 27. Trained: 0.008387220681955417. Validation: 0.012450287584215403.
# Starting epoch 28. Trained: 0.00828282010431091. Validation: 0.01185115531552583.
# Starting epoch 29. Trained: 0.008196922251954675. Validation: 0.011936503811739385.
# Starting epoch 30. Trained: 0.008139617818718156. Validation: 0.011704105767421424.
# Starting epoch 31. Trained: 0.008142267415920893. Validation: 0.01337286364287138.
# Starting epoch 32. Trained: 0.007900031562894583. Validation: 0.011475103092379868.
# Starting epoch 33. Trained: 0.007816741522401572. Validation: 0.011364649748429656.
# Starting epoch 34. Trained: 0.007815753668546676. Validation: 0.011050839093513787.
# Starting epoch 35. Trained: 0.00765302125364542. Validation: 0.012013134430162609.
# Starting epoch 36. Trained: 0.0076308042897532385. Validation: 0.012502991827204823.
# Starting epoch 37. Trained: 0.007483794912695884. Validation: 0.011508384137414396.
# Starting epoch 38. Trained: 0.0074317785911262035. Validation: 0.01242609485052526.
# Starting epoch 39. Trained: 0.007366036980723341. Validation: 0.011706334189511836.
# Starting epoch 40. Trained: 0.0073396712075918915. Validation: 0.011519764782860875.
# Best score: 0.011050839093513787
# --------------------
# Fold: 2
# Last val: 0.011519764782860875
# Best val: 0.011050839093513787
# --------------------
# Training set length: 119
# Validation set length: 29
# Testing set length: 29
# Validation loss before training: 0.6494817212224007
# Starting epoch 1. Trained: 0.6572296142578125. Validation: 0.6464652568101883.
# Starting epoch 2. Trained: 0.638708770275116. Validation: 0.6346143409609795.
# Starting epoch 3. Trained: 0.6161970893541971. Validation: 0.5991584286093712.
# Starting epoch 4. Trained: 0.5712827126185099. Validation: 0.5065110102295876.
# Starting epoch 5. Trained: 0.19495499345163506. Validation: 0.023055837955325842.
# Starting epoch 6. Trained: 0.018695365668584905. Validation: 0.016763734631240368.
# Starting epoch 7. Trained: 0.014912805892527104. Validation: 0.01595037430524826.
# Starting epoch 8. Trained: 0.013487122176835934. Validation: 0.016124385176226497.
# Starting epoch 9. Trained: 0.012736920018990834. Validation: 0.014307140721939504.
# Starting epoch 10. Trained: 0.012121508674075207. Validation: 0.014035566011443734.
# Starting epoch 11. Trained: 0.011553851515054702. Validation: 0.013638269272632897.
# Starting epoch 12. Trained: 0.011223488037164013. Validation: 0.013709559803828597.
# Starting epoch 13. Trained: 0.01083748321980238. Validation: 0.012346076080575585.
# Starting epoch 14. Trained: 0.010507726157084108. Validation: 0.012235044734552503.
# Starting epoch 15. Trained: 0.010222739834959308. Validation: 0.011933682253584266.
# Starting epoch 16. Trained: 0.010008704258749883. Validation: 0.011728470446541905.
# Starting epoch 17. Trained: 0.009707726910710335. Validation: 0.012782612815499306.
# Starting epoch 18. Trained: 0.009596213093027472. Validation: 0.01139604568015784.
# Starting epoch 19. Trained: 0.009467993242045244. Validation: 0.013281610095873475.
# Starting epoch 20. Trained: 0.009239113237708808. Validation: 0.01133953861426562.
# Starting epoch 21. Trained: 0.009065359256540735. Validation: 0.011426532291807234.
# Starting epoch 22. Trained: 0.009010133411114415. Validation: 0.011199178348761052.
# Starting epoch 23. Trained: 0.008922558495153983. Validation: 0.01274934655521065.
# Starting epoch 24. Trained: 0.008767715639745195. Validation: 0.011317527038045228.
# Starting epoch 25. Trained: 0.008617686045666536. Validation: 0.011187930591404438.
# Starting epoch 26. Trained: 0.008523881528526544. Validation: 0.011075418558903039.
# Starting epoch 27. Trained: 0.00841567775545021. Validation: 0.012785002822056413.
# Starting epoch 28. Trained: 0.008486328010136882. Validation: 0.012512621702626348.
# Starting epoch 29. Trained: 0.008361241593956948. Validation: 0.01168646098813042.
# Starting epoch 30. Trained: 0.008279648578415314. Validation: 0.011318003293126822.
# Starting epoch 31. Trained: 0.0081890708534047. Validation: 0.011299010599032044.
# Starting epoch 32. Trained: 0.008212970135112603. Validation: 0.011886504827998579.
# Starting epoch 33. Trained: 0.008168695960193872. Validation: 0.011557580903172493.
# Starting epoch 34. Trained: 0.008032747342561682. Validation: 0.011128930491395295.
# Starting epoch 35. Trained: 0.008028309528405468. Validation: 0.011391413281671703.
# Starting epoch 36. Trained: 0.007848981263426444. Validation: 0.011217683495488018.
# Starting epoch 37. Trained: 0.007816285469258825. Validation: 0.010831515653990209.
# Starting epoch 38. Trained: 0.007741097779944539. Validation: 0.011012735310941935.
# Starting epoch 39. Trained: 0.007643002970144153. Validation: 0.011307963461149484.
# Starting epoch 40. Trained: 0.0075323933580269415. Validation: 0.010642177832778543.
# Best score: 0.010642177832778543
# --------------------
# Fold: 3
# Last val: 0.010642177832778543
# Best val: 0.010642177832778543
# --------------------
# Training set length: 119
# Validation set length: 29
# Testing set length: 29
# Validation loss before training: 0.6338683888316154
# Starting epoch 1. Trained: 0.6158738772074381. Validation: 0.6261909678578377.
# Starting epoch 2. Trained: 0.5925523062547048. Validation: 0.6005887314677238.
# Starting epoch 3. Trained: 0.5671450694402059. Validation: 0.5550510808825493.
# Starting epoch 4. Trained: 0.5135999818642935. Validation: 0.4339398592710495.
# Starting epoch 5. Trained: 0.14531400389969348. Validation: 0.01790453738067299.
# Starting epoch 6. Trained: 0.0188695654583474. Validation: 0.01367053424473852.
# Starting epoch 7. Trained: 0.014942663162946701. Validation: 0.012757930904626846.
# Starting epoch 8. Trained: 0.01370519008487463. Validation: 0.01111763168592006.
# Starting epoch 9. Trained: 0.01286034161845843. Validation: 0.011496425024233758.
# Starting epoch 10. Trained: 0.01228665526335438. Validation: 0.011326684907544404.
# Starting epoch 11. Trained: 0.011754726540918152. Validation: 0.010494307498447597.
# Starting epoch 12. Trained: 0.011258585983887315. Validation: 0.010661548178177327.
# Starting epoch 13. Trained: 0.010834728290016452. Validation: 0.010282019735313952.
# Starting epoch 14. Trained: 0.010610592427353065. Validation: 0.009478899417445064.
# Starting epoch 15. Trained: 0.0103044836781919. Validation: 0.01029115857090801.
# Starting epoch 16. Trained: 0.009896654558057586. Validation: 0.009678864327725023.
# Starting epoch 17. Trained: 0.009845368734871348. Validation: 0.009394744469318539.
# Starting epoch 18. Trained: 0.009627507363135616. Validation: 0.009278002136852592.
# Starting epoch 19. Trained: 0.009447513210276762. Validation: 0.010292117134667933.
# Starting epoch 20. Trained: 0.009432020240152876. Validation: 0.009389526152517647.
# Starting epoch 21. Trained: 0.009236163987467686. Validation: 0.009458672313485295.
# Starting epoch 22. Trained: 0.009146428496266405. Validation: 0.009242423577234149.
# Starting epoch 23. Trained: 0.009009782581900556. Validation: 0.009692835039459169.
# Starting epoch 24. Trained: 0.008884079350779454. Validation: 0.009038241405505687.
# Starting epoch 25. Trained: 0.008793853518242637. Validation: 0.01013895688811317.
# Starting epoch 26. Trained: 0.008671131000543635. Validation: 0.008763939316850156.
# Starting epoch 27. Trained: 0.008572482985133927. Validation: 0.009809173352550715.
# Starting epoch 28. Trained: 0.00838478618922333. Validation: 0.009587232023477554.
# Starting epoch 29. Trained: 0.008489331183955073. Validation: 0.009985295473597944.
# Starting epoch 30. Trained: 0.008345950503523152. Validation: 0.009940632153302431.
# Starting epoch 31. Trained: 0.008326811731482546. Validation: 0.009691237122751772.
# Starting epoch 32. Trained: 0.00823433172578613. Validation: 0.009213042096234858.
# Starting epoch 33. Trained: 0.008139791215459507. Validation: 0.009281064267270267.
# Starting epoch 34. Trained: 0.008133847018082936. Validation: 0.009704827913083136.
# Starting epoch 35. Trained: 0.008077863696962595. Validation: 0.011585518077481538.
# Starting epoch 36. Trained: 0.007973977814738948. Validation: 0.010162200080230832.
# Starting epoch 37. Trained: 0.007900909365465244. Validation: 0.009393596556037664.
# Starting epoch 38. Trained: 0.00780286166506509. Validation: 0.010240786126814783.
# Starting epoch 39. Trained: 0.007695592474192381. Validation: 0.009933692344930023.
# Starting epoch 40. Trained: 0.007688728300854564. Validation: 0.009977274516131729.
# Best score: 0.008763939316850156
# --------------------
# Fold: 4
# Last val: 0.009977274516131729
# Best val: 0.008763939316850156
# --------------------
# -------------------------
# -----------END-----------
# -------------------------
# Best fold: 4
# Best validation loss: 0.008763939316850156
# Best epoch: 26
# Mean val of folds: 0.010323784314095974
# Best vals for each fold:
# Fold :1 - Val: 0.010869186138734221
# Fold :1 - Val: 0.010292779188603163
# Fold :1 - Val: 0.011050839093513787
# Fold :1 - Val: 0.010642177832778543
# Fold :1 - Val: 0.008763939316850156
