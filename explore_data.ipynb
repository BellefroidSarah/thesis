# %%
import os
import torch

import torchvision.transforms as transforms
import numpy as np
import constants as cst

from torchvision.ops import masks_to_boxes
from PIL import Image

# %%
transform = transforms.ToTensor()
total_pixels = 1932 * 2576

TERMS = cst.TERM_NAMES
#TERMS = ["br1a"]

for term in TERMS:
    mask_folder = "/notebooks/" + term
    
    percent_pixels = []
    horizontal_lengths = []
    vertical_lengths = []
    for file in os.listdir(mask_folder):
        mask = transform(Image.open(os.path.join(mask_folder, file)))
        mask = mask.type(torch.LongTensor)
        
        pixels = int(mask.sum())
        
        percent_pixels.append(pixels/total_pixels)
        
        obj_ids = torch.unique(mask)
        obj_ids = obj_ids[1:]
        
        masks = mask == obj_ids[:, None, None]
        
        box = masks_to_boxes(masks)
        
        h = box[0, 2].item() - box[0, 0].item()
        v = box[0, 3].item() - box[0, 1].item()
        horizontal_lengths.append(h)
        vertical_lengths.append(v)
        
    print("Term: " + term)
    print("Mean percentage of pixels: " + str(np.mean(percent_pixels) * 100))
    print("Mean horizontal: " + str(np.mean(horizontal_lengths)))
    print("Mean vertical: " + str(np.mean(vertical_lengths)))
    print()
# Out:
# Term: m1
# Mean percentage of pixels: 0.015205829633013982
# Mean horizontal: 30.570247933884296
# Mean vertical: 51.97520661157025
#
# Term: m2
# Mean percentage of pixels: 0.014927199458295203
# Mean horizontal: 31.172131147540984
# Mean vertical: 53.90163934426229
#
# Term: d1
# Mean percentage of pixels: 0.03768038093707698
# Mean horizontal: 106.14049586776859
# Mean vertical: 87.66115702479338
#
# Term: d2
# Mean percentage of pixels: 0.03791116517495467
# Mean horizontal: 105.23333333333333
# Mean vertical: 89.64166666666667
#
# Term: en1
# Mean percentage of pixels: 0.0764259974203461
# Mean horizontal: 207.66666666666666
# Mean vertical: 46.796747967479675
#
# Term: en2
# Mean percentage of pixels: 0.08509707001124638
# Mean horizontal: 211.77235772357724
# Mean vertical: 51.552845528455286
#
# Term: ch1
# Mean percentage of pixels: 0.07185006732911908
# Mean horizontal: 93.6470588235294
# Mean vertical: 78.5798319327731
#
# Term: ch2
# Mean percentage of pixels: 0.07366097360696333
# Mean horizontal: 93.22222222222223
# Mean vertical: 79.94871794871794
#
# Term: br2a
# Mean percentage of pixels: 0.030115446547580697
# Mean horizontal: 115.51807228915662
# Mean vertical: 79.19277108433735
#
# Term: br2b
# Mean percentage of pixels: 0.026741225214323823
# Mean horizontal: 112.5609756097561
# Mean vertical: 61.573170731707314
#
# Term: br1a
# Mean percentage of pixels: 0.07340077096938856
# Mean horizontal: 197.2396694214876
# Mean vertical: 56.94214876033058
#
# Term: br1b
# Mean percentage of pixels: 0.06870363441663126
# Mean horizontal: 196.23140495867767
# Mean vertical: 65.02479338842976
#
# Term: hm1
# Mean percentage of pixels: 0.059273348173086694
# Mean horizontal: 85.0
# Mean vertical: 65.39024390243902
#
# Term: hm2
# Mean percentage of pixels: 0.06344413603907324
# Mean horizontal: 87.49193548387096
# Mean vertical: 64.80645161290323
#
# Term: op1
# Mean percentage of pixels: 0.11709515274492012
# Mean horizontal: 125.66129032258064
# Mean vertical: 102.12096774193549
#
# Term: op2
# Mean percentage of pixels: 0.11359182294175066
# Mean horizontal: 128.19354838709677
# Mean vertical: 93.51612903225806
#
# Term: p
# Mean percentage of pixels: 0.6102852370291368
# Mean horizontal: 405.4274193548387
# Mean vertical: 141.73387096774192
#
# Term: n
# Mean percentage of pixels: 0.40030732302837774
# Mean horizontal: 331.95081967213116
# Mean vertical: 92.98360655737704
#
# Term: cb1
# Mean percentage of pixels: 0.15868047191871618
# Mean horizontal: 146.38655462184875
# Mean vertical: 155.16806722689077
#
# Term: cb2
# Mean percentage of pixels: 0.15860525228001554
# Mean horizontal: 151.5677966101695
# Mean vertical: 146.85593220338984
#
# Term: cl1
# Mean percentage of pixels: 0.10475294627707955
# Mean horizontal: 247.3781512605042
# Mean vertical: 157.14285714285714
#
# Term: cl2
# Mean percentage of pixels: 0.11213825930047956
# Mean horizontal: 259.7647058823529
# Mean vertical: 125.73949579831933
#
# Term: oc1
# Mean percentage of pixels: 0.0600934067929089
# Mean horizontal: 72.66386554621849
# Mean vertical: 73.94957983193277
#
# Term: oc2
# Mean percentage of pixels: 0.06095666367282747
# Mean horizontal: 66.84297520661157
# Mean vertical: 77.16528925619835
#
# Term: vc
# Mean percentage of pixels: 0.4016396222593614
# Mean horizontal: 459.3443396226415
# Mean vertical: 125.33962264150944
